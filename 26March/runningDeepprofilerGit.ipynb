# %%
# %%bash
# source activate deepprofenv

# %%
# %%bash
# # 1. Move to the first project
# cd "/media/arnout/Elements/Thesis/final/project_T1_neighbours_deduplication"
# # 2. Run profiling using the specific environment's python
# /home/arnout/miniconda3/envs/deepprofenv/bin/python3 -m deepprofiler --root="." --config=config.json profile

# %%
# %%bash
# # 1. Move to the first project
# cd "/media/arnout/Elements/Thesis/final/project_P3_neighbours_deduplication"
# # 2. Run profiling using the specific environment's python
# /home/arnout/miniconda3/envs/deepprofenv/bin/python3 -m deepprofiler --root="." --config=config.json profile
#
#
# # 1. Move to the first project
# cd "/media/arnout/Elements/Thesis/final/project_P4_neighbours_deduplication"
# # 2. Run profiling using the specific environment's python
# /home/arnout/miniconda3/envs/deepprofenv/bin/python3 -m deepprofiler --root="." --config=config.json profile
#
#
# cd "/media/arnout/Elements/Thesis/final/project_P5_neighbours_deduplication"
# # 2. Run profiling using the specific environment's python
# /home/arnout/miniconda3/envs/deepprofenv/bin/python3 -m deepprofiler --root="." --config=config.json profile

# %%
# %%bash
# # 1. Move to the first project
# cd "/media/arnout/Elements/Thesis/final/project_P4_neighbours_deduplication"
# # 2. Run profiling using the specific environment's python
# /home/arnout/miniconda3/envs/deepprofenv/bin/python3 -m deepprofiler --root="." --config=config.json profile

# %%
#26 march

# %%
# %%bash
# # 1. Move to the first project
# cd "/media/arnout/Elements1/Thesis/final/project_antibiotics"
# # 2. Run profiling using the specific environment's python
# /home/arnout/miniconda3/envs/deepprofenv/bin/python3 -m deepprofiler --root="." --config=config.json profile

# %%
#26 march feature check

import pandas as pd
import numpy as np
import os

# --- SETTINGS ---
# The path to your DeepProfiler .npz file
file_path = "/media/arnout/Elements1/Thesis/final/project_antibiotics/outputs/results/features/PLATE6_T1/A5/2"

# Choose where you want to save the CSV
output_dir = "/media/arnout/Elements1/Thesis/final/project_antibiotics/previews"
output_filename = "site_features_preview2.csv"
# ----------------

# Create the directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
    print(f"Created directory: {output_dir}")

full_save_path = os.path.join(output_dir, output_filename)

try:
    with np.load(file_path) as data:
        # DeepProfiler stores features under the key 'features'
        df = pd.DataFrame(data['features'])
        
        # Save to CSV at the chosen location
        df.to_csv(full_save_path, index=False)
        print(f"Successfully saved features to: {full_save_path}")
        
        # Optional: print the shape to verify (N cells x 1280 features for EfficientNet)
        print(f"Data shape: {df.shape}")

except Exception as e:
    print(f"Error: {e}")

# %%
#simpelere config

# %%bash
# 1. Move to the first project
cd "/media/arnout/Elements1/Thesis/final/antibiotics_simplerconfig"
# 2. Run profiling using the specific environment's python
/home/arnout/miniconda3/envs/deepprofenv/bin/python3 -m deepprofiler --root="." --config=config.json profile

# %%
# %%bash
# # 1. Move to the first project
# cd "/media/arnout/Elements1/Thesis/final/antibiotics_simplerconfig"
# # 2. Run profiling using the specific environment's python
# /home/arnout/miniconda3/envs/deepprofenv/bin/python3 -m deepprofiler --root="." --config=config.json profile

# %% [markdown]
# %%bash
# # 1. Move to the first project
# cd "/media/arnout/Elements/Thesis/final/project_P3_neighbours_deduplication"
# # 2. Run profiling using the specific environment's python
# /home/arnout/miniconda3/envs/deepprofenv/bin/python3 -m deepprofiler --root="." --config=config.json profile
#
#
# # 1. Move to the first project
# cd "/media/arnout/Elements/Thesis/final/project_P4_neighbours_deduplication"
# # 2. Run profiling using the specific environment's python
# /home/arnout/miniconda3/envs/deepprofenv/bin/python3 -m deepprofiler --root="." --config=config.json profile
#
#
# cd "/media/arnout/Elements/Thesis/final/project_P5_neighbours_deduplication"
# # 2. Run profiling using the specific environment's python
# /home/arnout/miniconda3/envs/deepprofenv/bin/python3 -m deepprofiler --root="." --config=config.json profile

# %%
# %%bash
# # 1. Move to the first project
# cd "/media/arnout/Elements/Thesis/final/project_P3_neighbours_deduplication"
# # 2. Run profiling using the specific environment's python
# /home/arnout/miniconda3/envs/deepprofenv/bin/python3 -m deepprofiler --root="." --config=config.json profile
#
#
# # 1. Move to the first project
# cd "/media/arnout/Elements/Thesis/final/project_P4_neighbours_deduplication"
# # 2. Run profiling using the specific environment's python
# /home/arnout/miniconda3/envs/deepprofenv/bin/python3 -m deepprofiler --root="." --config=config.json profile
#
#
# cd "/media/arnout/Elements/Thesis/final/project_P5_neighbours_deduplication"
# # 2. Run profiling using the specific environment's python
# /home/arnout/miniconda3/envs/deepprofenv/bin/python3 -m deepprofiler --root="." --config=config.json profile

# %%
# %%bash
# source activate deepprofenv
#
#
#
# python3 -m deepprofiler --root="/media/arnout/Elements/Thesis/project_deduplication_normalization" --config=config.json profile && \
# python3 -m deepprofiler --root="/media/arnout/Elements/Thesis/project_deduplication_normalizationT2" --config=config.json profile

# %%
# %%bash
# # 1. Move to the first project
# cd "/media/arnout/Elements/Thesis/project_deduplication_normalization"
# # 2. Run profiling using the specific environment's python
# /home/arnout/miniconda3/envs/deepprofenv/bin/python3 -m deepprofiler --root="." --config=config.json profile
#
# # 3. Move to the second project
# cd "/media/arnout/Elements/Thesis/project_deduplication_normalizationT2"
# # 4. Run the second one
# /home/arnout/miniconda3/envs/deepprofenv/bin/python3 -m deepprofiler --root="." --config=config.json profile
