# %%
from dataset import ImageDataset
from config import Config
from model import QualityModel, Trainer, get_data_loaders
import torch.optim as optim
import torch
import torch.nn as nn
import os
import matplotlib.pyplot as plt
import torch.nn as nn
from torchvision import models
from torch.utils.data import Dataset, DataLoader, random_split, ConcatDataset, WeightedRandomSampler
from torchvision import transforms
from dataset import ImageDataset
from config import Config
import numpy as np
import torch
from train import classify_and_move_images
from model import QualityModel
import torch
from config import Config
from torchvision import transforms
from remove_empty import remove_empty_bad_quality_folders
import os
import shutil
import torch
from torch.utils.data import DataLoader
from dataset import ImageDataset
from torchvision import transforms
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from config import Config
from model import QualityModel
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from dataset import ImageDataset
#       2 from config import Config
#       3 from model import QualityModel, Trainer, get_data_loaders
#
# File /vsc-hard-mounts/leuven-data/382/vsc38241/Code_quality_control/QC_nn/dataset.py:4
#       2 import os
#       3 import numpy as np
# ----> 4 import torch
#       5 import cv2
#       6 import tifffile as tiff
#
# ModuleNotFoundError: No module named 'torch'

# %%
# !pip install torch
# !pip install torchvision
# !pip install matplotlib
# !pip install numpy
# !pip install scikit-learn
# Out:
# Collecting torch
#   Downloading torch-2.9.1-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (30 kB)
# Collecting filelock (from torch)
#   Downloading filelock-3.20.1-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/arnout/miniconda3/envs/torch_env/lib/python3.10/site-packages (from torch) (4.15.0)
# Collecting sympy>=1.13.3 (from torch)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch)
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec>=0.8.5 (from torch)
#   Downloading fsspec-2025.12.0-py3-none-any.whl.metadata (10 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.8.93 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-runtime-cu12==12.8.90 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-cupti-cu12==12.8.90 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cudnn-cu12==9.10.2.21 (from torch)
#   Downloading nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cublas-cu12==12.8.4.1 (from torch)
#   Downloading nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cufft-cu12==11.3.3.83 (from torch)
#   Downloading nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-curand-cu12==10.3.9.90 (from torch)
#   Downloading nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cusolver-cu12==11.7.3.90 (from torch)
#   Downloading nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusparse-cu12==12.5.8.93 (from torch)
#   Downloading nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusparselt-cu12==0.7.1 (from torch)
#   Downloading nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl.metadata (7.0 kB)
# Collecting nvidia-nccl-cu12==2.27.5 (from torch)
#   Downloading nvidia_nccl_cu12-2.27.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvshmem-cu12==3.3.20 (from torch)
#   Downloading nvidia_nvshmem_cu12-3.3.20-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# Collecting nvidia-nvtx-cu12==12.8.90 (from torch)
#   Downloading nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvjitlink-cu12==12.8.93 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cufile-cu12==1.13.1.3 (from torch)
#   Downloading nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting triton==3.5.1 (from torch)
#   Downloading triton-3.5.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.7 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Downloading markupsafe-3.0.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.7 kB)
# Downloading torch-2.9.1-cp310-cp310-manylinux_2_28_x86_64.whl (899.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 899.8/899.8 MB 23.7 MB/s  0:00:22m0:00:0100:01
# Downloading nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl (594.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.3/594.3 MB 35.5 MB/s  0:00:12m0:00:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 27.0 MB/s  0:00:00m0:00:01
# Downloading nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (88.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 48.4 MB/s  0:00:01m0:00:0100:01
# Downloading nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (954 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.8/954.8 kB 7.4 MB/s  0:00:00
# Downloading nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl (706.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.8/706.8 MB 24.2 MB/s  0:00:17m0:00:0100:01
# Downloading nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (193.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 MB 37.1 MB/s  0:00:05m0:00:0100:01
# Downloading nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 10.7 MB/s  0:00:00
# Downloading nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl (63.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 MB 44.6 MB/s  0:00:01m0:00:0100:01
# Downloading nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl (267.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.5/267.5 MB 46.2 MB/s  0:00:05m0:00:0100:01
# Downloading nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (288.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 MB 36.0 MB/s  0:00:07m0:00:0100:01
# Downloading nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl (287.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.2/287.2 MB 46.1 MB/s  0:00:06m0:00:0100:01
# Downloading nvidia_nccl_cu12-2.27.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (322.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.3/322.3 MB 37.6 MB/s  0:00:07m0:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (39.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.3/39.3 MB 35.3 MB/s  0:00:01m0:00:0100:01
# Downloading nvidia_nvshmem_cu12-3.3.20-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (124.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.7/124.7 MB 42.2 MB/s  0:00:02m0:00:0100:01
# Downloading nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# Downloading triton-3.5.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (170.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.3/170.3 MB 36.6 MB/s  0:00:04m0:00:0100:01
# Downloading fsspec-2025.12.0-py3-none-any.whl (201 kB)
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 2.7 MB/s  0:00:00m eta 0:00:01
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 9.3 MB/s  0:00:006m0:00:01
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 505.0 kB/s  0:00:000:00:01
# Downloading filelock-3.20.1-py3-none-any.whl (16 kB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading markupsafe-3.0.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (20 kB)
# Installing collected packages: nvidia-cusparselt-cu12, mpmath, triton, sympy, nvidia-nvtx-cu12, nvidia-nvshmem-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, networkx, MarkupSafe, fsspec, filelock, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, jinja2, nvidia-cusolver-cu12, torch
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24/24 [torch]m23/24 [torch]-cusolver-cu12]2]2]
# Successfully installed MarkupSafe-3.0.3 filelock-3.20.1 fsspec-2025.12.0 jinja2-3.1.6 mpmath-1.3.0 networkx-3.4.2 nvidia-cublas-cu12-12.8.4.1 nvidia-cuda-cupti-cu12-12.8.90 nvidia-cuda-nvrtc-cu12-12.8.93 nvidia-cuda-runtime-cu12-12.8.90 nvidia-cudnn-cu12-9.10.2.21 nvidia-cufft-cu12-11.3.3.83 nvidia-cufile-cu12-1.13.1.3 nvidia-curand-cu12-10.3.9.90 nvidia-cusolver-cu12-11.7.3.90 nvidia-cusparse-cu12-12.5.8.93 nvidia-cusparselt-cu12-0.7.1 nvidia-nccl-cu12-2.27.5 nvidia-nvjitlink-cu12-12.8.93 nvidia-nvshmem-cu12-3.3.20 nvidia-nvtx-cu12-12.8.90 sympy-1.14.0 torch-2.9.1 triton-3.5.1
# Collecting torchvision
#   Downloading torchvision-0.24.1-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (5.9 kB)
# Collecting numpy (from torchvision)
#   Downloading numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: torch==2.9.1 in /home/arnout/miniconda3/envs/torch_env/lib/python3.10/site-packages (from torchvision) (2.9.1)
# Collecting pillow!=8.3.*,>=5.3.0 (from torchvision)
#   Downloading pillow-12.0.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Requirement already satisfied: filelock in /home/arnout/miniconda3/envs/torch_env/lib/python3.10/site-packages (from torch==2.9.1->torchvision) (3.20.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/arnout/miniconda3/envs/torch_env/lib/python3.10/site-packages (from torch==2.9.1->torchvision) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/arnout/miniconda3/envs/torch_env/lib/python3.10/site-packages (from torch==2.9.1->torchvision) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/arnout/miniconda3/envs/torch_env/lib/python3.10/site-packages (from torch==2.9.1->torchvision) (3.4.2)
# Requirement already satisfied: jinja2 in /home/arnout/miniconda3/envs/torch_env/lib/python3.10/site-packages (from torch==2.9.1->torchvision) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/arnout/miniconda3/envs/torch_env/lib/python3.10/site-packages (from torch==2.9.1->torchvision) (2025.12.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/arnout/miniconda3/envs/torch_env/lib/python3.10/site-packages (from torch==2.9.1->torchvision) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/arnout/miniconda3/envs/torch_env/lib/python3.10/site-packages (from torch==2.9.1->torchvision) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/arnout/miniconda3/envs/torch_env/lib/python3.10/site-packages (from torch==2.9.1->torchvision) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/arnout/miniconda3/envs/torch_env/lib/python3.10/site-packages (from torch==2.9.1->torchvision) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/arnout/miniconda3/envs/torch_env/lib/python3.10/site-packages (from torch==2.9.1->torchvision) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/arnout/miniconda3/envs/torch_env/lib/python3.10/site-packages (from torch==2.9.1->torchvision) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/arnout/miniconda3/envs/torch_env/lib/python3.10/site-packages (from torch==2.9.1->torchvision) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/arnout/miniconda3/envs/torch_env/lib/python3.10/site-packages (from torch==2.9.1->torchvision) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/arnout/miniconda3/envs/torch_env/lib/python3.10/site-packages (from torch==2.9.1->torchvision) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/arnout/miniconda3/envs/torch_env/lib/python3.10/site-packages (from torch==2.9.1->torchvision) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/arnout/miniconda3/envs/torch_env/lib/python3.10/site-packages (from torch==2.9.1->torchvision) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /home/arnout/miniconda3/envs/torch_env/lib/python3.10/site-packages (from torch==2.9.1->torchvision) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/arnout/miniconda3/envs/torch_env/lib/python3.10/site-packages (from torch==2.9.1->torchvision) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/arnout/miniconda3/envs/torch_env/lib/python3.10/site-packages (from torch==2.9.1->torchvision) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/arnout/miniconda3/envs/torch_env/lib/python3.10/site-packages (from torch==2.9.1->torchvision) (1.13.1.3)
# Requirement already satisfied: triton==3.5.1 in /home/arnout/miniconda3/envs/torch_env/lib/python3.10/site-packages (from torch==2.9.1->torchvision) (3.5.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/arnout/miniconda3/envs/torch_env/lib/python3.10/site-packages (from sympy>=1.13.3->torch==2.9.1->torchvision) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/arnout/miniconda3/envs/torch_env/lib/python3.10/site-packages (from jinja2->torch==2.9.1->torchvision) (3.0.3)
# Downloading torchvision-0.24.1-cp310-cp310-manylinux_2_28_x86_64.whl (8.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 20.5 MB/s  0:00:00m0:00:0100:01
# Downloading pillow-12.0.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 31.6 MB/s  0:00:00 eta 0:00:01
# Downloading numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 40.3 MB/s  0:00:00m0:00:01
# Installing collected packages: pillow, numpy, torchvision
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [torchvision] [torchvision]
# Successfully installed numpy-2.2.6 pillow-12.0.0 torchvision-0.24.1
# Collecting matplotlib
#   Downloading matplotlib-3.10.8-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (52 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.61.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (114 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.9-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.23 in /home/arnout/miniconda3/envs/torch_env/lib/python3.10/site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in /home/arnout/miniconda3/envs/torch_env/lib/python3.10/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /home/arnout/miniconda3/envs/torch_env/lib/python3.10/site-packages (from matplotlib) (12.0.0)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/arnout/miniconda3/envs/torch_env/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/arnout/miniconda3/envs/torch_env/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.8-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 8.3 MB/s  0:00:016m0:00:0100:01
# Downloading contourpy-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (325 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.61.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 6.0 MB/s  0:00:00m eta 0:00:01
# Downloading kiwisolver-1.4.9-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 2.3 MB/s  0:00:00m eta 0:00:01
# Downloading pyparsing-3.2.5-py3-none-any.whl (113 kB)
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [matplotlib]6 [matplotlib]
# Successfully installed contourpy-1.3.2 cycler-0.12.1 fonttools-4.61.1 kiwisolver-1.4.9 matplotlib-3.10.8 pyparsing-3.2.5
# Requirement already satisfied: numpy in /home/arnout/miniconda3/envs/torch_env/lib/python3.10/site-packages (2.2.6)
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.2-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.22.0 in /home/arnout/miniconda3/envs/torch_env/lib/python3.10/site-packages (from scikit-learn) (2.2.6)
# Collecting scipy>=1.8.0 (from scikit-learn)
#   Downloading scipy-1.15.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.7.2-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 21.5 MB/s  0:00:00m0:00:0100:01
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading scipy-1.15.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.7/37.7 MB 44.4 MB/s  0:00:00m0:00:0100:01
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [scikit-learn] [scikit-learn]
# Successfully installed joblib-1.5.3 scikit-learn-1.7.2 scipy-1.15.3 threadpoolctl-3.6.0

# %%
# config.py
import torch

class Config:
    # Paths
    DATA_DIR = "/media/arnout/BS5/qc_nn_bsubt_kd"
 
    #C:/Users/Bart/qc_nn/training_data"
    GOOD_DIR = f"{DATA_DIR}/Good"
    BAD_DIR = f"{DATA_DIR}/bad"
    MODEL_PATH = f"{DATA_DIR}/quality_model_best_m4_v2.pth"
    TEST_GOOD = f"{DATA_DIR}/Test/Good_test"
    TEST_BAD = f"{DATA_DIR}/Test/Bad_test"
    #TEST_GOOD = f"{DATA_DIR}/test_good"
    #TEST_BAD = f"{DATA_DIR}/test_bad"
    # Model parameters
    IMAGE_SIZE = (224, 224)
    BATCH_SIZE = 8
    VAL_SPLIT = 0.2
    EPOCHS = 1000
    PATIENCE = 5
    LEARNING_RATE = 0.0001
    
    # Device
    DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# dataset.py

# !pip install opencv-python
# !pip install tifffile

import os
import numpy as np
import torch
import cv2
import tifffile as tiff
from config import Config
from torch.utils.data import Dataset, DataLoader, random_split, ConcatDataset, WeightedRandomSampler
from torchvision import transforms
class ImageDataset(Dataset):
    def __init__(self, root_dir, transform=None, label=1):
        self.root_dir = root_dir
        self.transform = transform
        self.label = label
        self.images = [f for f in os.listdir(root_dir) if f.endswith("_C1.tiff")]

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        filename = self.images[idx]
        img_path = os.path.join(self.root_dir, filename)
        try:
            image = tiff.imread(img_path)
            if len(image.shape) == 3:
                image = image[..., 0]
            image = image.astype(np.float32) / 65535.0  # Normalize 16-bit TIFF
            image = cv2.resize(image, Config.IMAGE_SIZE)
            image = np.expand_dims(image, axis=-1)
            if self.transform:
                image = self.transform(image)
            return image.to(torch.float32), torch.tensor([self.label], dtype=torch.float32), filename
        except Exception as e:
            print(f"(Error: {e})")
            # Return a dummy sample along with its filename so that the worker doesn't crash
            dummy = np.zeros((Config.IMAGE_SIZE[1], Config.IMAGE_SIZE[0], 1), dtype=np.float32)
            dummy = cv2.resize(dummy, Config.IMAGE_SIZE)
            dummy = np.expand_dims(dummy, axis=-1)
            if self.transform:
                dummy = self.transform(dummy)
            return dummy.to(torch.float32), torch.tensor([self.label], dtype=torch.float32), filename
# Out:
# Requirement already satisfied: opencv-python in /home/arnout/miniconda3/envs/torch_env/lib/python3.10/site-packages (4.12.0.88)
# Requirement already satisfied: numpy<2.3.0,>=2 in /home/arnout/miniconda3/envs/torch_env/lib/python3.10/site-packages (from opencv-python) (2.2.6)
# Requirement already satisfied: tifffile in /home/arnout/miniconda3/envs/torch_env/lib/python3.10/site-packages (2025.5.10)
# Requirement already satisfied: numpy in /home/arnout/miniconda3/envs/torch_env/lib/python3.10/site-packages (from tifffile) (2.2.6)

# %%
#model.py
# !pip install tqdm

import torch.nn as nn
from torchvision import models
from torch.utils.data import Dataset, DataLoader, random_split, ConcatDataset, WeightedRandomSampler
from torchvision import transforms
from dataset import ImageDataset
from config import Config
import numpy as np
import torch

class QualityModel(nn.Module):
    def __init__(self):
        super(QualityModel, self).__init__()
        # Using EfficientNet instead of ResNet for better performance
        self.model = models.efficientnet_b0(weights=models.EfficientNet_B0_Weights.IMAGENET1K_V1)
        # Modify first conv layer for grayscale input
        self.model.features[0][0] = nn.Conv2d(1, 32, kernel_size=3, stride=2, padding=1, bias=False)
        # Modify classifier for binary output
        self.model.classifier[1] = nn.Linear(self.model.classifier[1].in_features, 1)

    def forward(self, x):
        return torch.sigmoid(self.model(x))

# data_utils.py
def get_data_loaders():
    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.ConvertImageDtype(torch.float32),
    ])

    good_dataset = ImageDataset(root_dir=Config.GOOD_DIR, transform=transform, label=1)
    bad_dataset = ImageDataset(root_dir=Config.BAD_DIR, transform=transform, label=0)

    # Split datasets
    good_train_size = int((1 - Config.VAL_SPLIT) * len(good_dataset))
    good_val_size = len(good_dataset) - good_train_size
    bad_train_size = int((1 - Config.VAL_SPLIT) * len(bad_dataset))
    bad_val_size = len(bad_dataset) - bad_train_size

    good_train, good_val = random_split(good_dataset, [good_train_size, good_val_size])
    bad_train, bad_val = random_split(bad_dataset, [bad_train_size, bad_val_size])

    train_dataset = ConcatDataset([good_train, bad_train])
    val_dataset = ConcatDataset([good_val, bad_val])

    # Create balanced sampler
    train_labels = np.array([int(sample[1].item()) for sample in train_dataset])
    class_counts = np.bincount(train_labels)
    class_weights = 1. / class_counts
    sample_weights = class_weights[train_labels]
    sampler = WeightedRandomSampler(sample_weights, num_samples=len(sample_weights), replacement=True)

    train_loader = DataLoader(train_dataset, batch_size=Config.BATCH_SIZE, sampler=sampler, num_workers=1)
    val_loader = DataLoader(val_dataset, batch_size=Config.BATCH_SIZE, shuffle=False, num_workers=1)

    return train_loader, val_loader

# trainer.py
from tqdm import tqdm

class Trainer:
    def __init__(self, model, train_loader, val_loader, criterion, optimizer, scheduler, device):
        self.model = model
        self.train_loader = train_loader
        self.val_loader = val_loader
        self.criterion = criterion
        self.optimizer = optimizer
        self.scheduler = scheduler
        self.device = device
        self.best_loss = float('inf')
        self.early_stop_count = 0

    def train_epoch(self, epoch):
        self.model.train()
        total_loss = 0
        progress_bar = tqdm(self.train_loader, desc=f"Epoch {epoch+1}/{Config.EPOCHS}")
        
        # Unpack three values (image, label, filename) and ignore the filename
        for inputs, labels, _ in progress_bar:
            inputs, labels = inputs.to(self.device), labels.to(self.device)
            
            self.optimizer.zero_grad()
            outputs = self.model(inputs)
            loss = self.criterion(outputs, labels)
            
            loss.backward()
            self.optimizer.step()
            
            total_loss += loss.item()
            progress_bar.set_postfix(loss=loss.item())
            
        return total_loss / len(self.train_loader)

    def validate(self):
        self.model.eval()
        total_loss = 0
        with torch.no_grad():
            for inputs, labels, _ in self.val_loader:  # Unpack and ignore the filename
                inputs, labels = inputs.to(self.device), labels.to(self.device)
                outputs = self.model(inputs)
                loss = self.criterion(outputs, labels)
                total_loss += loss.item()
        
        return total_loss / len(self.val_loader)
# Out:
# Requirement already satisfied: tqdm in /home/arnout/miniconda3/envs/torch_env/lib/python3.10/site-packages (4.67.1)

# %%
#train
from dataset import ImageDataset
from config import Config
from model import QualityModel, Trainer, get_data_loaders
import torch.optim as optim
import torch
import torch.nn as nn
import os
import matplotlib.pyplot as plt


def main():
    train_losses = []
    val_losses = []
    # Get data loaders
    train_loader, val_loader = get_data_loaders()
    print(f"✅ Training data: {len(train_loader.dataset)} images, "
          f"Validation data: {len(val_loader.dataset)} images")

    # Initialize model and training components
    model = QualityModel().to(Config.DEVICE)
    criterion = nn.BCELoss()
    optimizer = optim.AdamW(model.parameters(), lr=Config.LEARNING_RATE)
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', patience=2, factor=0.5)
    #scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', patience=2, factor=0.5, verbose=True)
    # Initialize trainer
    trainer = Trainer(model, train_loader, val_loader, criterion, optimizer, scheduler, Config.DEVICE)
    
    for epoch in range(Config.EPOCHS):
        train_loss = trainer.train_epoch(epoch)
        val_loss = trainer.validate()
        
        # Store losses
        train_losses.append(train_loss)
        val_losses.append(val_loss)
        
        print(f"Epoch {epoch+1}/{Config.EPOCHS}")
        print(f"Training Loss: {train_loss:.4f}")
        print(f"Validation Loss: {val_loss:.4f}")
        
        scheduler.step(val_loss)
        
        # Early stopping
        if val_loss < trainer.best_loss:
            trainer.best_loss = val_loss
            trainer.early_stop_count = 0
            torch.save(model.state_dict(), Config.MODEL_PATH)
            print("✅ Model improved & saved!")
        else:
            trainer.early_stop_count += 1
            print(f"Early stopping counter: {trainer.early_stop_count}/{Config.PATIENCE}")
            
        if trainer.early_stop_count >= Config.PATIENCE:
            print("⏹️ Early stopping triggered!")
            break
    
    # Visualization of loss curves after training
    plt.figure(figsize=(10, 5))
    plt.plot(train_losses, label='Training Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss')
    plt.legend()
    plt.show()
    
    print("🎉 Training complete!")

if __name__ == "__main__":
    main()

# inference.py
import shutil
from torch.utils.data import DataLoader
def classify_and_move_images(root_folder, model, transform):
    model.eval()
    
    # Get subfolders once
    subfolders = [f for f in os.listdir(root_folder) if os.path.isdir(os.path.join(root_folder, f))]

    for subfolder in subfolders:
        subfolder_path = os.path.join(root_folder, subfolder)
        bad_quality_folder = f"{subfolder_path}_bad_Q"
        os.makedirs(bad_quality_folder, exist_ok=True)

        # Create dataset and DataLoader (minimal memory footprint with batch_size=1)
        dataset = ImageDataset(subfolder_path, transform=transform)
        dataloader = DataLoader(dataset, batch_size=1, shuffle=False, num_workers=0)  # num_workers=0 to avoid memory overhead

        for img_tensor, _, filename in dataloader:
            # Only evaluate images ending with _C1.tiff
            if not filename[0].endswith("_C1.tiff"):
                continue

            img_tensor = img_tensor.to(Config.DEVICE)
            with torch.no_grad():
                prediction = model(img_tensor).item()

            # Explicitly delete tensor to free memory
            del img_tensor
            if torch.cuda.is_available():
                torch.cuda.empty_cache()

            # Move files if low quality
            if prediction < 0.5:
                base = filename[0].replace("_C1.tiff", "")
                for suffix in ["_C1.tiff", "_C2.tiff", "_C3.tiff", "_C4.tiff", "_C5.tiff"]:
                    target_filename = base + suffix
                    source_path = os.path.join(subfolder_path, target_filename)
                    if os.path.exists(source_path):
                        shutil.move(source_path, os.path.join(bad_quality_folder, target_filename))
                        print(f"Moved {target_filename} to {bad_quality_folder}")

        print(f"Processed folder: {subfolder_path}")

    # Final cleanup
    if torch.cuda.is_available():
        torch.cuda.empty_cache()
# Out:
# ✅ Training data: 345 images, Validation data: 87 images
# Epoch 1/1000: 100%|██████████| 44/44 [00:21<00:00,  2.08it/s, loss=0.636]
# Epoch 1/1000
# Training Loss: 0.5854
# Validation Loss: 0.7718
# ✅ Model improved & saved!
# Epoch 2/1000: 100%|██████████| 44/44 [00:20<00:00,  2.10it/s, loss=0.567]
# Epoch 2/1000
# Training Loss: 0.4890
# Validation Loss: 0.3828
# ✅ Model improved & saved!
# Epoch 3/1000: 100%|██████████| 44/44 [00:20<00:00,  2.14it/s, loss=0.558]
# Epoch 3/1000
# Training Loss: 0.4157
# Validation Loss: 0.3256
# ✅ Model improved & saved!
# Epoch 4/1000: 100%|██████████| 44/44 [00:21<00:00,  2.07it/s, loss=0.637]
# Epoch 4/1000
# Training Loss: 0.4156
# Validation Loss: 0.3744
# Early stopping counter: 1/5
# Epoch 5/1000: 100%|██████████| 44/44 [00:21<00:00,  2.09it/s, loss=0.703]
# Epoch 5/1000
# Training Loss: 0.3195
# Validation Loss: 0.4066
# Early stopping counter: 2/5
# Epoch 6/1000: 100%|██████████| 44/44 [00:20<00:00,  2.16it/s, loss=0.834]
# Epoch 6/1000
# Training Loss: 0.3655
# Validation Loss: 0.3483
# Early stopping counter: 3/5
# Epoch 7/1000: 100%|██████████| 44/44 [00:21<00:00,  2.04it/s, loss=0.549]
# Epoch 7/1000
# Training Loss: 0.2826
# Validation Loss: 0.3820
# Early stopping counter: 4/5
# Epoch 8/1000: 100%|██████████| 44/44 [00:21<00:00,  2.08it/s, loss=0.542]
# Epoch 8/1000
# Training Loss: 0.2792
# Validation Loss: 0.3043
# ✅ Model improved & saved!
# Epoch 9/1000: 100%|██████████| 44/44 [00:20<00:00,  2.10it/s, loss=0.882]
# Epoch 9/1000
# Training Loss: 0.2652
# Validation Loss: 0.3749
# Early stopping counter: 1/5
# Epoch 10/1000: 100%|██████████| 44/44 [00:20<00:00,  2.17it/s, loss=0.525]
# Epoch 10/1000
# Training Loss: 0.2154
# Validation Loss: 0.2691
# ✅ Model improved & saved!
# Epoch 11/1000: 100%|██████████| 44/44 [00:20<00:00,  2.20it/s, loss=0.581]
# Epoch 11/1000
# Training Loss: 0.2618
# Validation Loss: 0.2959
# Early stopping counter: 1/5
# Epoch 12/1000: 100%|██████████| 44/44 [00:19<00:00,  2.22it/s, loss=0.56]
# Epoch 12/1000
# Training Loss: 0.2505
# Validation Loss: 0.3241
# Early stopping counter: 2/5
# Epoch 13/1000: 100%|██████████| 44/44 [00:21<00:00,  2.09it/s, loss=0.763]
# Epoch 13/1000
# Training Loss: 0.2024
# Validation Loss: 0.3657
# Early stopping counter: 3/5
# Epoch 14/1000: 100%|██████████| 44/44 [00:21<00:00,  2.05it/s, loss=0.629]
# Epoch 14/1000
# Training Loss: 0.2536
# Validation Loss: 0.3012
# Early stopping counter: 4/5
# Epoch 15/1000: 100%|██████████| 44/44 [00:21<00:00,  2.06it/s, loss=0.722]
# Epoch 15/1000
# Training Loss: 0.2059
# Validation Loss: 0.3594
# Early stopping counter: 5/5
# ⏹️ Early stopping triggered!
# 🎉 Training complete!

# %%
#gewoon om te runnen met oude model, als je nieuw model wilt runnen moet deze code weg en moet je elke cel runnen
#train
from dataset import ImageDataset
from config import Config
from model import QualityModel, Trainer, get_data_loaders
import torch.optim as optim
import torch
import torch.nn as nn
import os
import matplotlib.pyplot as plt




# inference.py
import shutil
from torch.utils.data import DataLoader
def classify_and_move_images(root_folder, model, transform):
    model.eval()
    
    # Get subfolders once
    subfolders = [f for f in os.listdir(root_folder) if os.path.isdir(os.path.join(root_folder, f))]

    for subfolder in subfolders:
        subfolder_path = os.path.join(root_folder, subfolder)
        bad_quality_folder = f"{subfolder_path}_bad_Q"
        os.makedirs(bad_quality_folder, exist_ok=True)

        # Create dataset and DataLoader (minimal memory footprint with batch_size=1)
        dataset = ImageDataset(subfolder_path, transform=transform)
        dataloader = DataLoader(dataset, batch_size=1, shuffle=False, num_workers=0)  # num_workers=0 to avoid memory overhead

        for img_tensor, _, filename in dataloader:
            # Only evaluate images ending with _C1.tiff
            if not filename[0].endswith("_C1.tiff"):
                continue

            img_tensor = img_tensor.to(Config.DEVICE)
            with torch.no_grad():
                prediction = model(img_tensor).item()

            # Explicitly delete tensor to free memory
            del img_tensor
            if torch.cuda.is_available():
                torch.cuda.empty_cache()

            # Move files if low quality
            if prediction < 0.5:
                base = filename[0].replace("_C1.tiff", "")
                for suffix in ["_C1.tiff", "_C2.tiff", "_C3.tiff", "_C4.tiff", "_C5.tiff"]:
                    target_filename = base + suffix
                    source_path = os.path.join(subfolder_path, target_filename)
                    if os.path.exists(source_path):
                        shutil.move(source_path, os.path.join(bad_quality_folder, target_filename))
                        print(f"Moved {target_filename} to {bad_quality_folder}")

        print(f"Processed folder: {subfolder_path}")

    # Final cleanup
    if torch.cuda.is_available():
        torch.cuda.empty_cache()

# %%
#evaluate model
import os
import shutil
import torch
from torch.utils.data import DataLoader
from dataset import ImageDataset
from torchvision import transforms
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from config import Config
from model import QualityModel


DATA_DIR = "/media/arnout/BS5/qc_nn_bsubt_kd"
TEST_GOOD = f"{DATA_DIR}/Test/Good_test"
TEST_BAD = f"{DATA_DIR}/Test/Bad_test"

# Load the model
model = QualityModel().to(Config.DEVICE)
model.load_state_dict(torch.load(Config.MODEL_PATH, weights_only=True))
model.eval()

# Define the transformations
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.ConvertImageDtype(torch.float32),
])

# Load the test datasets
test_good_dataset = ImageDataset(TEST_GOOD, transform=transform, label=1)
test_bad_dataset = ImageDataset(TEST_BAD, transform=transform, label=0)

# Create data loaders
test_good_loader = DataLoader(test_good_dataset, batch_size=Config.BATCH_SIZE, shuffle=False)
test_bad_loader = DataLoader(test_bad_dataset, batch_size=Config.BATCH_SIZE, shuffle=False)

# Function to evaluate the model
def evaluate_model(loader, label):
    all_preds = []
    all_labels = []
    wrong_preds = []
    with torch.no_grad():
        for images, _, filenames in loader:
            for img_tensor, filename in zip(images, filenames):
                # Only evaluate images ending with _C1.tiff
                if not filename.endswith("_C1.tiff"):
                    continue

                img_tensor = img_tensor.to(Config.DEVICE)
                prediction = model(img_tensor.unsqueeze(0)).item()

                # Convert prediction to binary class
                pred_label = 1 if prediction >= 0.5 else 0
                all_preds.append(pred_label)
                all_labels.append(label)

                # Check if the prediction is wrong
                if pred_label != label:
                    wrong_preds.append(filename)
    return all_preds, all_labels, wrong_preds

# Evaluate on good and bad test sets
good_preds, good_labels, good_wrong_preds = evaluate_model(test_good_loader, 1)
bad_preds, bad_labels, bad_wrong_preds = evaluate_model(test_bad_loader, 0)

# Combine results
all_preds = good_preds + bad_preds
all_labels = good_labels + bad_labels
wrong_preds = good_wrong_preds + bad_wrong_preds

# Calculate metrics
accuracy = accuracy_score(all_labels, all_preds)
precision = precision_score(all_labels, all_preds, zero_division=0)
recall = recall_score(all_labels, all_preds, zero_division=0)
f1 = f1_score(all_labels, all_preds, zero_division=0)

# Print metrics
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")

# Print wrongfully predicted samples
print("Wrongfully predicted samples:")
for filename in wrong_preds:
    print(filename)
# Out:
# Accuracy: 0.8947
# Precision: 0.9091
# Recall: 0.9091
# F1 Score: 0.9091
# Wrongfully predicted samples:
# Sample_B6_XY5_C1.tiff
# Sample_C10_XY0_C1.tiff
# Sample_F3_XY0_C1.tiff
# Sample_A1_XY10_C1.tiff

# %%
#inference
from train import classify_and_move_images
from model import QualityModel
import torch
from config import Config
from torchvision import transforms
from remove_empty import remove_empty_bad_quality_folders

#base_path = 'I:/Export Bart/Stationary_phase_screen'
#plate_ids = ['89B', 'AA', 'AB', 'B']  # Add more plate IDs as needed
base_path = '/media/arnout/Elements/antibioticscreenTiff'
plate_ids = ['6_T1', '7_T1']
#plate_ids = ['1_T0','1_T1','1_T2','2_T0','2_T2','3_T0','3_T1','3_T2','4_T0','4_T1','4_T2','5_T0_T1','5_T2' ]  # Add more plate IDs as needed
ev_dirs = [f"{base_path}/PLATE{plate_id}" for plate_id in plate_ids]

# Create transform
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.ConvertImageDtype(torch.float32),
])

# Load model
model = QualityModel().to(Config.DEVICE)
print('Device:', Config.DEVICE)
#model.load_state_dict(torch.load(Config.MODEL_PATH))

model.load_state_dict(torch.load("/media/arnout/Elements/Thesis/backupcode quality control/Modelperformance/modelFinaal_17_12/quality_model_best_m4_v2.pth"))
# Loop through each directory
for ev_dir in ev_dirs:
    print(f"Processing directory: {ev_dir}")
    classify_and_move_images(ev_dir, model, transform)
    remove_empty_bad_quality_folders(ev_dir)
    print(f"Finished processing: {ev_dir}")
# Out:
# /home/arnout/miniconda3/envs/torch_env/lib/python3.10/site-packages/torch/cuda/__init__.py:283: UserWarning:
#     Found GPU0 Quadro M6000 24GB which is of cuda capability 5.2.
#     Minimum and Maximum cuda capability supported by this version of PyTorch is
#     (7.0) - (12.0)
#
#   warnings.warn(
# /home/arnout/miniconda3/envs/torch_env/lib/python3.10/site-packages/torch/cuda/__init__.py:304: UserWarning:
#     Please install PyTorch with a following CUDA
#     configurations:  12.6 following instructions at
#     https://pytorch.org/get-started/locally/
#
#   warnings.warn(matched_cuda_warn.format(matched_arches))
# /home/arnout/miniconda3/envs/torch_env/lib/python3.10/site-packages/torch/cuda/__init__.py:326: UserWarning:
# Quadro M6000 24GB with CUDA capability sm_52 is not compatible with the current PyTorch installation.
# The current PyTorch install supports CUDA capabilities sm_70 sm_75 sm_80 sm_86 sm_90 sm_100 sm_120.
# If you want to use the Quadro M6000 24GB GPU with PyTorch, please check the instructions at https://pytorch.org/get-started/locally/
#
#   warnings.warn(
# Device: cuda
# Processing directory: /media/arnout/Elements/antibioticscreenTiff/PLATE6_T1
# ---------------------------------------------------------------------------
# AcceleratorError                          Traceback (most recent call last)
# Cell In[1], line 31
#      29 for ev_dir in ev_dirs:
#      30     print(f"Processing directory: {ev_dir}")
# ---> 31     classify_and_move_images(ev_dir, model, transform)
#      32     remove_empty_bad_quality_folders(ev_dir)
#      33     print(f"Finished processing: {ev_dir}")
#
# File /media/arnout/Elements/Thesis/backupcode quality control/Modelperformance/train.py:96, in classify_and_move_images(root_folder, model, transform)
#      94 img_tensor = img_tensor.to(Config.DEVICE)
#      95 with torch.no_grad():
# ---> 96     prediction = model(img_tensor).item()
#      98 # Explicitly delete tensor to free memory
#      99 del img_tensor
#
# File ~/miniconda3/envs/torch_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/torch_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File /media/arnout/Elements/Thesis/backupcode quality control/Modelperformance/model.py:21, in QualityModel.forward(self, x)
#      20 def forward(self, x):
# ---> 21     return torch.sigmoid(self.model(x))
#
# File ~/miniconda3/envs/torch_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/torch_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/torch_env/lib/python3.10/site-packages/torchvision/models/efficientnet.py:344, in EfficientNet.forward(self, x)
#     343 def forward(self, x: Tensor) -> Tensor:
# --> 344     return self._forward_impl(x)
#
# File ~/miniconda3/envs/torch_env/lib/python3.10/site-packages/torchvision/models/efficientnet.py:334, in EfficientNet._forward_impl(self, x)
#     333 def _forward_impl(self, x: Tensor) -> Tensor:
# --> 334     x = self.features(x)
#     336     x = self.avgpool(x)
#     337     x = torch.flatten(x, 1)
#
# File ~/miniconda3/envs/torch_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/torch_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/torch_env/lib/python3.10/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     246 """
#     247 Runs the forward pass.
#     248 """
#     249 for module in self:
# --> 250     input = module(input)
#     251 return input
#
# File ~/miniconda3/envs/torch_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/torch_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/torch_env/lib/python3.10/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     246 """
#     247 Runs the forward pass.
#     248 """
#     249 for module in self:
# --> 250     input = module(input)
#     251 return input
#
# File ~/miniconda3/envs/torch_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/torch_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/torch_env/lib/python3.10/site-packages/torch/nn/modules/activation.py:473, in SiLU.forward(self, input)
#     469 def forward(self, input: Tensor) -> Tensor:
#     470     """
#     471     Runs the forward pass.
#     472     """
# --> 473     return F.silu(input, inplace=self.inplace)
#
# File ~/miniconda3/envs/torch_env/lib/python3.10/site-packages/torch/nn/functional.py:2370, in silu(input, inplace)
#    2368     return handle_torch_function(silu, (input,), input, inplace=inplace)
#    2369 if inplace:
# -> 2370     return torch._C._nn.silu_(input)
#    2371 return torch._C._nn.silu(input)
#
# AcceleratorError: CUDA error: no kernel image is available for execution on the device
# Search for `cudaErrorNoKernelImageForDevice' in https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html for more information.
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
#25march test
import os
import torch
from torchvision import transforms
from pathlib import Path

# Local imports from your project
from train import classify_and_move_images
from model import QualityModel
from remove_empty import remove_empty_bad_quality_folders

# --- SETTINGS ---
DEVICE = torch.device("cpu")
MODEL_FILE = "/media/arnout/Elements/Thesis/backupcode quality control/Modelperformance/modelFinaal_17_12/quality_model_best_m4_v2.pth"
BASE_PATH = Path('/media/arnout/Elements/antibioticscreenTiff')
PLATE_IDS = ['6_T1', '7_T1']

# Generate directory list
ev_dirs = [BASE_PATH / f"PLATE{pid}" for pid in PLATE_IDS]

# --- PREPARATION ---
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.ConvertImageDtype(torch.float32),
])

# Safety check
if not os.path.exists(MODEL_FILE):
    raise FileNotFoundError(f"Could not find model at {MODEL_FILE}. Check your drive mount!")

# Load model
model = QualityModel().to(DEVICE)
model.load_state_dict(torch.load(MODEL_FILE, map_location=DEVICE))
model.eval() # Good practice to ensure dropout/batchnorm are in eval mode
print(f'Running on: {DEVICE}')

# --- EXECUTION ---
for ev_dir in ev_dirs:
    if not ev_dir.exists():
        print(f"⚠️ Skipping missing directory: {ev_dir}")
        continue
        
    print(f"🚀 Processing: {ev_dir}")
    # Using str(ev_dir) if your functions expect strings instead of Path objects
    classify_and_move_images(str(ev_dir), model, transform)
    remove_empty_bad_quality_folders(str(ev_dir))
    print(f"✅ Finished: {ev_dir}")
# Out:
# Running on: cpu
# 🚀 Processing: /media/arnout/Elements/antibioticscreenTiff/PLATE6_T1
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 45
#      43 print(f"🚀 Processing: {ev_dir}")
#      44 # Using str(ev_dir) if your functions expect strings instead of Path objects
# ---> 45 classify_and_move_images(str(ev_dir), model, transform)
#      46 remove_empty_bad_quality_folders(str(ev_dir))
#      47 print(f"✅ Finished: {ev_dir}")
#
# File /media/arnout/Elements/Thesis/backupcode quality control/Modelperformance/train.py:96, in classify_and_move_images(root_folder, model, transform)
#      94 img_tensor = img_tensor.to(Config.DEVICE)
#      95 with torch.no_grad():
# ---> 96     prediction = model(img_tensor).item()
#      98 # Explicitly delete tensor to free memory
#      99 del img_tensor
#
# File ~/miniconda3/envs/torch_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/torch_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File /media/arnout/Elements/Thesis/backupcode quality control/Modelperformance/model.py:21, in QualityModel.forward(self, x)
#      20 def forward(self, x):
# ---> 21     return torch.sigmoid(self.model(x))
#
# File ~/miniconda3/envs/torch_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/torch_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/torch_env/lib/python3.10/site-packages/torchvision/models/efficientnet.py:344, in EfficientNet.forward(self, x)
#     343 def forward(self, x: Tensor) -> Tensor:
# --> 344     return self._forward_impl(x)
#
# File ~/miniconda3/envs/torch_env/lib/python3.10/site-packages/torchvision/models/efficientnet.py:334, in EfficientNet._forward_impl(self, x)
#     333 def _forward_impl(self, x: Tensor) -> Tensor:
# --> 334     x = self.features(x)
#     336     x = self.avgpool(x)
#     337     x = torch.flatten(x, 1)
#
# File ~/miniconda3/envs/torch_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/torch_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/torch_env/lib/python3.10/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     246 """
#     247 Runs the forward pass.
#     248 """
#     249 for module in self:
# --> 250     input = module(input)
#     251 return input
#
# File ~/miniconda3/envs/torch_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/torch_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/torch_env/lib/python3.10/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     246 """
#     247 Runs the forward pass.
#     248 """
#     249 for module in self:
# --> 250     input = module(input)
#     251 return input
#
# File ~/miniconda3/envs/torch_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/torch_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/torch_env/lib/python3.10/site-packages/torch/nn/modules/conv.py:548, in Conv2d.forward(self, input)
#     547 def forward(self, input: Tensor) -> Tensor:
# --> 548     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/miniconda3/envs/torch_env/lib/python3.10/site-packages/torch/nn/modules/conv.py:543, in Conv2d._conv_forward(self, input, weight, bias)
#     531 if self.padding_mode != "zeros":
#     532     return F.conv2d(
#     533         F.pad(
#     534             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)
#     541         self.groups,
#     542     )
# --> 543 return F.conv2d(
#     544     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     545 )
#
# RuntimeError: Input type (torch.cuda.FloatTensor) and weight type (torch.FloatTensor) should be the same

# %%
import torch

# 1. Get your GPU name and Compute Capability
if torch.cuda.is_available():
    prop = torch.cuda.get_device_properties(0)
    print(f"GPU: {prop.name}")
    print(f"Compute Capability: {prop.major}.{prop.minor}")
    
    # 2. Check what this version of Torch supports
    print(f"Supported Archs: {torch.cuda.get_arch_list()}")
else:
    print("CUDA not available")
# Out:
# GPU: Quadro M6000 24GB
# Compute Capability: 5.2
# Supported Archs: ['sm_70', 'sm_75', 'sm_80', 'sm_86', 'sm_90', 'sm_100', 'sm_120']

# %%
import os
import torch
from torchvision import transforms
from pathlib import Path

# 1. Force everything to CPU to avoid the "No Kernel" and "Device Mismatch" errors
DEVICE = torch.device("cpu")

# Import Config and immediately override its device setting
from config import Config
Config.DEVICE = DEVICE 

# Local imports from your project
from train import classify_and_move_images
from model import QualityModel
from remove_empty import remove_empty_bad_quality_folders

# --- SETTINGS ---
MODEL_FILE = "/media/arnout/Elements/Thesis/backupcode quality control/Modelperformance/modelFinaal_17_12/quality_model_best_m4_v2.pth"
BASE_PATH = Path('/media/arnout/Elements/antibioticscreenTiff')
PLATE_IDS = ['6_T1', '7_T1']

# Generate directory list
ev_dirs = [BASE_PATH / f"PLATE{pid}" for pid in PLATE_IDS]

# --- PREPARATION ---
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.ConvertImageDtype(torch.float32),
])

# Safety check for model file
if not os.path.exists(MODEL_FILE):
    raise FileNotFoundError(f"Could not find model at {MODEL_FILE}. Check your drive mount!")

# Load model explicitly to CPU
print(f"🔄 Loading model to {DEVICE}...")
model = QualityModel().to(DEVICE)

# map_location=DEVICE ensures the weights are loaded to CPU even if saved on GPU
state_dict = torch.load(MODEL_FILE, map_location=DEVICE)
model.load_state_dict(state_dict)
model.eval() 

print(f"🚀 Running on: {DEVICE}")

# --- EXECUTION ---
for ev_dir in ev_dirs:
    if not ev_dir.exists():
        print(f"⚠️ Skipping missing directory: {ev_dir}")
        continue
        
    print(f"--- Processing: {ev_dir} ---")
    
    try:
        # We pass the strings as your functions expect them
        # Note: Since we updated Config.DEVICE above, 
        # classify_and_move_images will now use CPU internally.
        classify_and_move_images(str(ev_dir), model, transform)
        remove_empty_bad_quality_folders(str(ev_dir))
        print(f"✅ Finished: {ev_dir}")
        
    except Exception as e:
        print(f"❌ Error processing {ev_dir}: {e}")

print("\n✨ All scheduled plates have been processed.")
# Out:
# 🔄 Loading model to cpu...
# 🚀 Running on: cpu
# --- Processing: /media/arnout/Elements/antibioticscreenTiff/PLATE6_T1 ---
# Processed folder: /media/arnout/Elements/antibioticscreenTiff/PLATE6_T1/Sample_B6
# Processed folder: /media/arnout/Elements/antibioticscreenTiff/PLATE6_T1/Sample_D3
# Moved Sample_F10_XY0_C1.tiff to /media/arnout/Elements/antibioticscreenTiff/PLATE6_T1/Sample_F10_bad_Q
# Moved Sample_F10_XY0_C2.tiff to /media/arnout/Elements/antibioticscreenTiff/PLATE6_T1/Sample_F10_bad_Q
# Moved Sample_F10_XY0_C3.tiff to /media/arnout/Elements/antibioticscreenTiff/PLATE6_T1/Sample_F10_bad_Q
# Moved Sample_F10_XY0_C4.tiff to /media/arnout/Elements/antibioticscreenTiff/PLATE6_T1/Sample_F10_bad_Q
# Moved Sample_F10_XY0_C5.tiff to /media/arnout/Elements/antibioticscreenTiff/PLATE6_T1/Sample_F10_bad_Q
# Moved Sample_F10_XY3_C1.tiff to /media/arnout/Elements/antibioticscreenTiff/PLATE6_T1/Sample_F10_bad_Q
# Moved Sample_F10_XY3_C2.tiff to /media/arnout/Elements/antibioticscreenTiff/PLATE6_T1/Sample_F10_bad_Q
#
tiff to /media/arnout/Elements/antibioticscreenTiff/PLATE7_T1/Sample_C3_bad_Q
# Moved Sample_C3_XY18_C3.tiff to /media/arnout/Elements/antibioticscreenTiff/PLATE7_T1/Sample_C3_bad_Q
# Moved Sample_C3_XY18_C4.tiff to /media/arnout/Elements/antibioticscreenTiff/PLATE7_T1/Sample_C3_bad_Q
# Moved Sample_C3_XY18_C5.tiff to /media/arnout/Elements/antibioticscreenTiff/PLATE7_T1/Sample_C3_bad_Q
# Processed folder: /media/arnout/Elements/antibioticscreenTiff/PLATE7_T1/Sample_C3
# Removed empty directory: /media/arnout/Elements/antibioticscreenTiff/PLATE7_T1/Sample_A6_bad_Q
# Removed empty directory: /media/arnout/Elements/antibioticscreenTiff/PLATE7_T1/Sample_C4_bad_Q
# Removed empty directory: /media/arnout/Elements/antibioticscreenTiff/PLATE7_T1/Sample_C5_bad_Q
# Removed empty directory: /media/arnout/Elements/antibioticscreenTiff/PLATE7_T1/Sample_C6_bad_Q
# Removed empty directory: /media/arnout/Elements/antibioticscreenTiff/PLATE7_T1/Sample_C8_bad_Q
# Removed empty directory: /media/arnout/Elements/antibioticscreenTiff/PLATE7_T1/Sample_D10_bad_Q
# Removed empty directory: /media/arnout/Elements/antibioticscreenTiff/PLATE7_T1/Sample_E9_bad_Q
# ✅ Finished: /media/arnout/Elements/antibioticscreenTiff/PLATE7_T1
#
# ✨ All scheduled plates have been processed.

# %%
import os
import shutil

def move_back_files(root_folder):
    """
    Moves files from directories ending with '_bad_Q' back to their original folders.
    The original folder is assumed to be the same as the '_bad_Q' folder with that suffix removed.
    """
    # List all directories in root_folder ending with "_bad_Q"
    for folder_name in os.listdir(root_folder):
        folder_path = os.path.join(root_folder, folder_name)
        if os.path.isdir(folder_path) and folder_name.endswith("_bad_Q"):
            # Determine the original folder name by removing the "_bad_Q" suffix
            original_folder_name = folder_name[:-6]  # Remove last 6 characters ("_bad_Q")
            original_folder_path = os.path.join(root_folder, original_folder_name)

            if not os.path.exists(original_folder_path):
                print(f"Original folder '{original_folder_path}' does not exist. Skipping '{folder_path}'.")
                continue

            # Move all files from the bad folder back to the original folder
            for file in os.listdir(folder_path):
                source_path = os.path.join(folder_path, file)
                target_path = os.path.join(original_folder_path, file)
                try:
                    shutil.move(source_path, target_path)
                    print(f"Moved '{file}' from '{folder_path}' back to '{original_folder_path}'.")
                except Exception as e:
                    print(f"Error moving '{file}': {e}")

            # Optionally, remove the empty bad folder
            try:
                os.rmdir(folder_path)
                print(f"Removed empty folder '{folder_path}'.")
            except Exception as e:
                print(f"Could not remove folder '{folder_path}': {e}")

if __name__ == "__main__":
    base_path = '/media/arnout/BS5/ScreenCrisprI_Arnout/Bstubt_KD_screen'
    plate_ids = ['1_T0','1_T1','1_T2','2_T0','2_T2','3_T0','3_T1','3_T2','4_T0','4_T1','4_T2','5_T0_T1','5_T2' ]
     # Add more plate IDs as needed

    ev_dirs = [f"{base_path}/PLATE{plate_id}" for plate_id in plate_ids]
    for ev_dir in ev_dirs:
        print(f"Processing directory: {ev_dir}")
        move_back_files(ev_dir)
        print(f"Finished processing: {ev_dir}")
# Out:
# Processing directory: /media/arnout/BS5/ScreenCrisprI_Arnout/Bstubt_KD_screen/PLATE1_T0
# Finished processing: /media/arnout/BS5/ScreenCrisprI_Arnout/Bstubt_KD_screen/PLATE1_T0
# Processing directory: /media/arnout/BS5/ScreenCrisprI_Arnout/Bstubt_KD_screen/PLATE1_T1
# Finished processing: /media/arnout/BS5/ScreenCrisprI_Arnout/Bstubt_KD_screen/PLATE1_T1
# Processing directory: /media/arnout/BS5/ScreenCrisprI_Arnout/Bstubt_KD_screen/PLATE1_T2
# Finished processing: /media/arnout/BS5/ScreenCrisprI_Arnout/Bstubt_KD_screen/PLATE1_T2
# Processing directory: /media/arnout/BS5/ScreenCrisprI_Arnout/Bstubt_KD_screen/PLATE2_T0
# Finished processing: /media/arnout/BS5/ScreenCrisprI_Arnout/Bstubt_KD_screen/PLATE2_T0
# Processing directory: /media/arnout/BS5/ScreenCrisprI_Arnout/Bstubt_KD_screen/PLATE2_T2
# Finished processing: /media/arnout/BS5/ScreenCrisprI_Arnout/Bstubt_KD_screen/PLATE2_T2
# Processing directory: /media/arnout/BS5/ScreenCrisprI_Arnout/Bstubt_KD_screen/PLATE3_T0
# Finished processing: /media/arnout/BS5/ScreenCrisprI_Arnout/Bstubt_KD_screen/PLATE3_T0
# Processing directory: /media/arnout/BS5/ScreenCrisprI_Arnout/Bstubt_KD_screen/PLATE3_T1
# Finished processing: /media/arnout/BS5/ScreenCrisprI_Arnout/Bstubt_KD_screen/PLATE3_T1
# Processing directory: /media/arnout/BS5/ScreenCrisprI_Arnout/Bstubt_KD_screen/PLATE3_T2
# Finished processing: /media/arnout/BS5/ScreenCrisprI_Arnout/Bstubt_KD_screen/PLATE3_T2
# Processing directory: /media/arnout/BS5/ScreenCrisprI_Arnout/Bstubt_KD_screen/PLATE4_T0
# Finished processing: /media/arnout/BS5/ScreenCrisprI_Arnout/Bstubt_KD_screen/PLATE4_T0
# Processing directory: /media/arnout/BS5/ScreenCrisprI_Arnout/Bstubt_KD_screen/PLATE4_T1
# Finished processing: /media/arnout/BS5/ScreenCrisprI_Arnout/Bstubt_KD_screen/PLATE4_T1
# Processing directory: /media/arnout/BS5/ScreenCrisprI_Arnout/Bstubt_KD_screen/PLATE4_T2
# Finished processing: /media/arnout/BS5/ScreenCrisprI_Arnout/Bstubt_KD_screen/PLATE4_T2
# Processing directory: /media/arnout/BS5/ScreenCrisprI_Arnout/Bstubt_KD_screen/PLATE5_T0_T1
# Finished processing: /media/arnout/BS5/ScreenCrisprI_Arnout/Bstubt_KD_screen/PLATE5_T0_T1
# Processing directory: /media/arnout/BS5/ScreenCrisprI_Arnout/Bstubt_KD_screen/PLATE5_T2
# Finished processing: /media/arnout/BS5/ScreenCrisprI_Arnout/Bstubt_KD_screen/PLATE5_T2

# %%
import os
import torch
from torchvision import transforms
from train import classify_and_move_images
from model import QualityModel
from config import Config
from remove_empty import remove_empty_bad_quality_folders

# 1. Update the base path to point to your Scratch via the link
# This uses the 'view_scratch' link you created in your home directory
base_path = os.path.expanduser('~/view_scratch') 

# 2. Update to your specific Plate ID
plate_ids = ['2_T1'] # Combined with 'PLATE' below, this looks for PLATE2_T1

# Construct the list of directories to process
ev_dirs = [f"{base_path}/PLATE{plate_id}" for plate_id in plate_ids]

# Create transform
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.ConvertImageDtype(torch.float32),
])

# Load model
model = QualityModel().to(Config.DEVICE)
print('Device:', Config.DEVICE)
model.load_state_dict(torch.load(Config.MODEL_PATH))

# Loop through each directory
for ev_dir in ev_dirs:
    if os.path.exists(ev_dir):
        print(f"Processing directory: {ev_dir}")
        classify_and_move_images(ev_dir, model, transform)
        remove_empty_bad_quality_folders(ev_dir)
        print(f"Finished processing: {ev_dir}")
    else:
        print(f"Error: Directory not found at {ev_dir}")
# Out:
# Device: cuda
# Processing directory: /user/leuven/382/vsc38241/view_scratch/PLATE2_T1
# Moved Sample_G9_XY17_C1.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_G9_bad_Q
# Moved Sample_G9_XY17_C2.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_G9_bad_Q
# Moved Sample_G9_XY17_C3.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_G9_bad_Q
# Moved Sample_G9_XY17_C4.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_G9_bad_Q
# Moved Sample_G9_XY17_C5.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_G9_bad_Q
# Moved Sample_G9_XY0_C1.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_G9_bad_Q
# Moved Sample_G9_XY0_C2.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_G9_bad_Q
# Moved Sample_G9_XY0_C3.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_G9_bad_Q
# Moved Sample_G9_XY0_C4.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_G9_bad_Q
# Moved Sample_G9_XY0_C5.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_G9_bad_Q
# Moved Sample_G9_XY2_C1.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_G9_bad_Q
# Moved Sample_G9_XY2_C2.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_G9_bad_Q
# Moved Sample_G9_XY2_C3.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_G9_bad_Q
# Moved Sample_G9_XY2_C4.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_G9_bad_Q
# Moved Sample_G9_XY2_C5.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_G9_bad_Q
# Processed folder: /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_G9
# Moved Sample_B6_XY4_C1.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_B6_bad_Q
# Moved Sample_B6_XY4_C2.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_B6_bad_Q
# Moved Sample_B6_XY4_C3.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_B6_bad_Q
# Moved Sample_B6_XY4_C4.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_B6_bad_Q
# Moved Sample_B6_XY4_C5.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_B6_bad_Q
# Moved Sample_B6_XY19_C1.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_B6_bad_Q
# Moved Sample_B6_XY19_C2.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_B6_bad_Q
# Moved Sample_B6_XY19_C3.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_B6_bad_Q
# Moved Sample_B6_XY19_C4.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_B6_bad_Q
# Moved Sample_B6_XY19_C5.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_B6_bad_Q
# Processed folder: /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_B6
# Processed folder: /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_E5
# Moved Sample_A6_XY12_C1.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_A6_bad_Q
# Moved Sample_A6_XY12_C2.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_A6_bad_Q
# Moved Sample_A6_XY12_C3.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_A6_bad_Q
# Moved Sample_A6_XY12_C4.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_A6_bad_Q
# Moved Sample_A6_XY12_C5.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_A6_bad_Q
# Moved Sample_A6_XY10_C1.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_A6_bad_Q
# Moved Sample_A6_XY10_C2.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_A6_bad_Q
# Moved Sample_A6_XY10_C3.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_A6_bad_Q
# Moved Sample_A6_XY10_C4.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_A6_bad_Q
# Moved Sample_A6_XY10_C5.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_A6_bad_Q
# Processed folder: /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_A6
# Moved Sample_B5_XY18_C1.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_B5_bad_Q
# Moved Sample_B5_XY18_C2.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_B5_bad_Q
# Moved Sample_B5_XY18_C3.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_B5_bad_Q
# Moved Sample_B5_XY18_C4.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_B5_bad_Q
# Moved Sample_B5_XY18_C5.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_B5_bad_Q
# Processed folder: /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_B5
# Moved Sample_F11_XY16_C1.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_F11_bad_Q
# Moved Sample_F11_XY16_C2.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_F11_bad_Q
# Moved Sample_F11_XY16_C3.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_F11_bad_Q
# Moved Sample_F11_XY16_C4.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_F11_bad_Q
# Moved Sample_F11_XY16_C5.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_F11_bad_Q
# Processed folder: /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_F11
# Processed folder: /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_B3
# Moved Sample_F7_XY14_C1.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_F7_bad_Q
# Moved Sample_F7_XY14_C2.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_F7_bad_Q
# Moved Sample_F7_XY14_C3.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_F7_bad_Q
# Moved Sample_F7_XY14_C4.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_F7_bad_Q
# Moved Sample_F7_XY14_C5.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_F7_bad_Q
# Processed folder: /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_F7
# Moved Sample_D6_XY5_C1.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_D6_bad_Q
# Moved Sample_D6_XY5_C2.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_D6_bad_Q
# Moved Sample_D6_XY5_C3.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_D6_bad_Q
# Moved Sample_D6_XY5_C4.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_D6_bad_Q
# Moved Sample_D6_XY5_C5.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_D6_bad_Q
# Moved Sample_D6_XY1_C1.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_D6_bad_Q
# Moved Sample_D6_XY1_C2.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_D6_bad_Q
# Moved Sample_D6_XY1_C3.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_D6_bad_Q
# Moved Sample_D6_XY1_C4.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_D6_bad_Q
# Moved Sample_D6_XY1_C5.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_D6_bad_Q
# Moved Sample_D6_XY12_C1.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_D6_bad_Q
# Moved Sample_D6_XY12_C2.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_D6_bad_Q
# Moved Sample_D6_XY12_C3.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_D6_bad_Q
# Moved Sample_D6_XY12_C4.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_D6_bad_Q
# Moved Sample_D6_XY12_C5.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_D6_bad_Q
# Moved Sample_D6_XY14_C1.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_D6_bad_Q
# Moved Sample_D6_XY14_C2.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_D6_bad_Q
# Moved Sample_D6_XY14_C3.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_D6_bad_Q
# Moved Sample_D6_XY14_C4.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_D6_bad_Q
# Moved Sample_D6_XY14_C5.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_D6_bad_Q
# Processed folder: /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_D6
# Moved Sample_F1_XY0_C1.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_F1_bad_Q
# Moved Sample_F1_XY0_C2.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_F1_bad_Q
# Moved Sample_F1_XY0_C3.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_F1_bad_Q
# Moved Sample_F1_XY0_C4.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_F1_bad_Q
# Moved Sample_F1_XY0_C5.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_F1_bad_Q
# Moved Sample_F1_XY15_C1.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_F1_bad_Q
# Moved Sample_F1_XY15_C2.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_F1_bad_Q
# Moved Sample_F1_XY15_C3.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_F1_bad_Q
# Moved Sample_F1_XY15_C4.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_F1_bad_Q
# Moved Sample_F1_XY15_C5.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_F1_bad_Q
# Moved Sample_F1_XY18_C1.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_F1_bad_Q
# Moved Sample_F1_XY18_C2.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_F1_bad_Q
# Moved Sample_F1_XY18_C3.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_F1_bad_Q
# Moved Sample_F1_XY18_C4.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_F1_bad_Q
# Moved Sample_F1_XY18_C5.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_F1_bad_Q
# Processed folder: /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_F1
# Moved Sample_A1_XY2_C1.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_A1_bad_Q
# Moved Sample_A1_XY2_C2.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_A1_bad_Q
# Moved Sample_A1_XY2_C3.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_A1_bad_Q
# Moved Sample_A1_XY2_C4.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_A1_bad_Q
# Moved Sample_A1_XY2_C5.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_A1_bad_Q
# Moved Sample_A1_XY3_C1.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_A1_bad_Q
# Moved Sample_A1_XY3_C2.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_A1_bad_Q
# Moved Sample_A1_XY3_C3.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_A1_bad_Q
# Moved Sample_A1_XY3_C4.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_A1_bad_Q
# Moved Sample_A1_XY3_C5.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_A1_bad_Q
# Processed folder: /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_A1
# Moved Sample_C9_XY10_C1.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_C9_bad_Q
# Moved Sample_C9_XY10_C2.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_C9_bad_Q
# Moved Sample_C9_XY10_C3.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_C9_bad_Q
# Moved Sample_C9_XY10_C4.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_C9_bad_Q
# Moved Sample_C9_XY10_C5.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_C9_bad_Q
# Processed folder: /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_C9
# Moved Sample_B10_XY10_C1.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_B10_bad_Q
# Moved Sample_B10_XY10_C2.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_B10_bad_Q
# Moved Sample_B10_XY10_C3.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_B10_bad_Q
# Moved Sample_B10_XY10_C4.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_B10_bad_Q
# Moved Sample_B10_XY10_C5.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_B10_bad_Q
# Moved Sample_B10_XY11_C1.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_B10_bad_Q
# Moved Sample_B10_XY11_C2.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_B10_bad_Q
# Moved Sample_B10_XY11_C3.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_B10_bad_Q
# Moved Sample_B10_XY11_C4.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_B10_bad_Q
# Moved Sample_B10_XY11_C5.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_B10_bad_Q
# Moved Sample_B10_XY12_C1.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_B10_bad_Q
# Moved Sample_B10_XY12_C2.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_B10_bad_Q
# Moved Sample_B10_XY12_C3.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_B10_bad_Q
# Moved Sample_B10_XY12_C4.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_B10_bad_Q
# Moved Sample_B10_XY12_C5.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_B10_bad_Q
# Processed folder: /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_B10
# Processed folder: /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_G4
# Moved Sample_D4_XY8_C1.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_D4_bad_Q
# Moved Sample_D4_XY8_C2.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_D4_bad_Q
# Moved Sample_D4_XY8_C3.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_D4_bad_Q
# Moved Sample_D4_XY8_C4.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_D4_bad_Q
# Moved Sample_D4_XY8_C5.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_D4_bad_Q
# Processed folder: /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_D4
# Moved Sample_C2_XY10_C1.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_C2_bad_Q
# Moved Sample_C2_XY10_C2.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_C2_bad_Q
# Moved Sample_C2_XY10_C3.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_C2_bad_Q
# Moved Sample_C2_XY10_C4.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_C2_bad_Q
# Moved Sample_C2_XY10_C5.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_C2_bad_Q
# Moved Sample_C2_XY9_C1.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_C2_bad_Q
# Moved Sample_C2_XY9_C2.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_C2_bad_Q
# Moved Sample_C2_XY9_C3.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_C2_bad_Q
# Moved Sample_C2_XY9_C4.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_C2_bad_Q
# Moved Sample_C2_XY9_C5.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_C2_bad_Q
# Processed folder: /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_C2
# Processed folder: /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_B9
# Moved Sample_C6_XY13_C1.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_C6_bad_Q
# Moved Sample_C6_XY13_C2.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_C6_bad_Q
# Moved Sample_C6_XY13_C3.tiff to /user/leuven/382/vsc38241/view_scratch/PLATE2_T1/Sample_